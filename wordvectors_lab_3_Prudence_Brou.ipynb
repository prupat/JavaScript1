# %% [markdown]
# <a href="https://colab.research.google.com/github/prupat/JavaScript1/blob/main/wordvectors_lab_3_Prudence_Brou.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Wordvectors lab
#
# ### Background
# The purpose of this lab is to explore the process of transforming words into numerical representations, and then understanding those values spatially. By the end of this lab (and corresponding lecture), you should be comfortable with the fact that computers transform text into numbers based on the context in which they appear.
#
# There are **two** parts to this lab:
#
# * **Part 1**: We'll train our own vectors on a very small corpus to understand vector similarity in a contextualized setting. We'll explore what vectors look like, how words are related, and the vocabulary of a model.
# * **Part 2**: GloVe word embeddings. GloVe is an unsupervised learning algorithm to calculate the vectors of the words in a corpus. We will use the pre-trained version that comes from Wikipedia articles. You can find [more about the GloVe vectors here](https://nlp.stanford.edu/projects/glove/). The goal of this section is to understand general word embeddings as trained on a very large corpus.

# %% [markdown]
# * `re` is the regular expression library
# * `gensim` is for representing documents as vectors. It's the library built for making word vectors.

# %% [markdown]
# ## Part 1: Gensim

# %%
import re
import nltk
import numpy as np
import matplotlib.pyplot as plt
import random

from gensim.models import Word2Vec

from sklearn.decomposition import IncrementalPCA
from sklearn.manifold import TSNE

# %% [markdown]
# Load a file and replace the markup characters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# I stored locally the The Project Gutenberg eBook of The Picture of Dorian Gray
file = open("/content/drive/MyDrive/Colab Notebooks/dorian_gray.txt", 'r').read()

# first, remove unwanted new line and tab characters from the text
for char in ["\n", "\r", "\d", "\t"]:
    file = file.replace(char, " ")

# check
print(file[:100])
# Out:
# ﻿The Project Gutenberg eBook of The Picture of Dorian Gray      This ebook is for the use of anyone

# %% [markdown]
# Clean the text a little bit (tokenize, lowercase)

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# this is simplified for demonstration
def sample_clean_text(text: str):
    # step 1: tokenize the text into sentences
    sentences = nltk.sent_tokenize(text)

    # step 2: tokenize each sentence into words
    tokenized_sentences = [nltk.word_tokenize(sent) for sent in sentences]

    # step 3: convert each word to lowercase
    tokenized_text = [[word.lower() for word in sent] for sent in tokenized_sentences]

    # return your tokens
    return tokenized_text

# call the function
tokens = sample_clean_text(text = file)

# check
print(tokens[:10])
# Out:
# [['\ufeffthe', 'project', 'gutenberg', 'ebook', 'of', 'the', 'picture', 'of', 'dorian', 'gray', 'this', 'ebook', 'is', 'for', 'the', 'use', 'of', 'anyone', 'anywhere', 'in', 'the', 'united', 'states', 'and', 'most', 'other', 'parts', 'of', 'the', 'world', 'at', 'no', 'cost', 'and', 'with', 'almost', 'no', 'restrictions', 'whatsoever', '.'], ['you', 'may', 'copy', 'it', ',', 'give', 'it', 'away', 'or', 're-use', 'it', 'under', 'the', 'terms', 'of', 'the', 'project', 'gutenberg', 'license', 'included', 'with', 'this', 'ebook', 'or', 'online', 'at', 'www.gutenberg.org', '.'], ['if', 'you', 'are', 'not', 'located', 'in', 'the', 'united', 'states', ',', 'you', 'will', 'have', 'to', 'check', 'the', 'laws', 'of', 'the', 'country', 'where', 'you', 'are', 'located', 'before', 'using', 'this', 'ebook', '.'], ['title', ':', 'the', 'picture', 'of', 'dorian', 'gray', 'author', ':', 'oscar', 'wilde', 'release', 'date', ':', 'october', '1', ',', '1994', '[', 'ebook', '#', '174', ']', 'most', 'recently', 'updated', ':', 'february', '3', ',', '2022', 'language', ':', 'english', '*', '*', '*', 'start', 'of', 'the', 'project', 'gutenberg', 'ebook', 'the', 'picture', 'of', 'dorian', 'gray', '*', '*', '*', 'the', 'picture', 'of', 'dorian', 'gray', 'by', 'oscar', 'wilde', 'contents', 'the', 'preface', 'chapter', 'i', '.'], ['chapter', 'ii', '.'], ['chapter', 'iii', '.'], ['chapter', 'iv', '.'], ['chapter', 'v.', 'chapter', 'vi', '.'], ['chapter', 'vii', '.'], ['chapter', 'viii', '.']]

# %% [markdown]
# Establish the [word2vec ](https://www.tensorflow.org/text/tutorials/word2vec#:~:text=word2vec%20is%20not%20a%20singular,downstream%20natural%20language%20processing%20tasks.)model. We've given it our list of tokens. We said that for each token, we want to define it in the context of 100 words.
#
# This means that each vector will have 100 numbers in it representing the relationship between this word and 100 others.
#
# The larger this number is, the better the model. The smaller the number, the worse the model.

# %%
model = Word2Vec(tokens,vector_size=100)

# %% [markdown]
# Now explore the entire vocabulary (note that only 1000 are represented because of the interface -- there are far more words in the vocab). Use this for ideas in the next section

# %%
model.wv.key_to_index
# Out:
# {',': 0,
#  '.': 1,
#  'the': 2,
#  'of': 3,
#  'and': 4,
#  'to': 5,
#  'a': 6,
#  'i': 7,
#  '“': 8,
#  '”': 9,
#  'he': 10,
#  'you': 11,
#  'that': 12,
#  'it': 13,
#  'in': 14,
#  'was': 15,
#  'his': 16,
#  'is': 17,
#  'had': 18,
#  '’': 19,
#  'with': 20,
#  'him': 21,
#  'for': 22,
#  'as': 23,
#  '?': 24,
#  'at': 25,
#  'have': 26,
#  'not': 27,
#  'me': 28,
#  'be': 29,
#  'one': 30,
#  'her': 31,
#  'she': 32,
#  't': 33,
#  'dorian': 34,
#  'what': 35,
#  'but': 36,
#  'are': 37,
#  '!': 38,
#  'on': 39,
#  'there': 40,
#  'they': 41,
#  'would': 42,
#  'my': 43,
#  'all': 44,
#  'or': 45,
#  'from': 46,
#  's': 47,
#  'said': 48,
#  'don': 49,
#  'were': 50,
#  'lord': 51,
#  'so': 52,
#  'if': 53,
#  'by': 54,
#  'been': 55,
#  'henry': 56,
#  'an': 57,
#  'am': 58,
#  'about': 59,
#  'who': 60,
#  'no': 61,
#  'some': 62,
#  'life': 63,
#  'when': 64,
#  'your': 65,
#  'like': 66,
#  'will': 67,
#  'them': 68,
#  'gray': 69,
#  'can': 70,
#  'this': 71,
#  'do': 72,
#  'man': 73,
#  'we': 74,
#  'never': 75,
#  'has': 76,
#  'know': 77,
#  'harry': 78,
#  'over': 79,
#  'must': 80,
#  'into': 81,
#  'out': 82,
#  ';': 83,
#  'their': 84,
#  'any': 85,
#  'basil': 86,
#  'up': 87,
#  'how': 88,
#  'then': 89,
#  'could': 90,
#  'more': 91,
#  'own': 92,
#  'now': 93,
#  'its': 94,
#  'things': 95,
#  'which': 96,
#  'see': 97,
#  'very': 98,
#  'than': 99,
#  'think': 100,
#  'come': 101,
#  'something': 102,
#  'seemed': 103,
#  'thing': 104,
#  'us': 105,
#  'should': 106,
#  'only': 107,
#  'go': 108,
#  'always': 109,
#  'made': 110,
#  'love': 111,
#  'quite': 112,
#  'eyes': 113,
#  'want': 114,
#  'time': 115,
#  'face': 116,
#  'himself': 117,
#  'good': 118,
#  'really': 119,
#  'too': 120,
#  'after': 121,
#  'people': 122,
#  'away': 123,
#  'did': 124,
#  'down': 125,
#  'back': 126,
#  'came': 127,
#  'cried': 128,
#  'looked': 129,
#  'world': 130,
#  'say': 131,
#  'tell': 132,
#  'why': 133,
#  'hallward': 134,
#  'look': 135,
#  'nothing': 136,
#  'project': 137,
#  'work': 138,
#  'room': 139,
#  'answered': 140,
#  'much': 141,
#  'other': 142,
#  'little': 143,
#  'going': 144,
#  'upon': 145,
#  'through': 146,
#  'thought': 147,
#  'sibyl': 148,
#  'such': 149,
#  'shall': 150,
#  'most': 151,
#  'round': 152,
#  'mr.': 153,
#  'yes': 154,
#  'told': 155,
#  'ever': 156,
#  'our': 157,
#  'once': 158,
#  'felt': 159,
#  'great': 160,
#  'before': 161,
#  'dear': 162,
#  'art': 163,
#  'men': 164,
#  'long': 165,
#  'picture': 166,
#  'yet': 167,
#  'lady': 168,
#  'young': 169,
#  'again': 170,
#  'anything': 171,
#  'moment': 172,
#  'let': 173,
#  'everything': 174,
#  'women': 175,
#  'those': 176,
#  'door': 177,
#  'make': 178,
#  'hand': 179,
#  'went': 180,
#  'being': 181,
#  'two': 182,
#  'old': 183,
#  'across': 184,
#  'asked': 185,
#  'might': 186,
#  'soul': 187,
#  'passed': 188,
#  'afraid': 189,
#  'night': 190,
#  'where': 191,
#  'every': 192,
#  'well': 193,
#  'day': 194,
#  'looking': 195,
#  'wonderful': 196,
#  'gutenberg™': 197,
#  'vane': 198,
#  'table': 199,
#  'turned': 200,
#  'got': 201,
#  'beauty': 202,
#  'lips': 203,
#  'right': 204,
#  'left': 205,
#  'course': 206,
#  'even': 207,
#  'head': 208,
#  'portrait': 209,
#  'lad': 210,
#  'white': 211,
#  'hands': 212,
#  'sir': 213,
#  'believe': 214,
#  'house': 215,
#  'better': 216,
#  'done': 217,
#  'still': 218,
#  ':': 219,
#  'horrible': 220,
#  'here': 221,
#  'oh': 222,
#  'found': 223,
#  'first': 224,
#  'may': 225,
#  'curious': 226,
#  'last': 227,
#  'suddenly': 228,
#  'rather': 229,
#  'knew': 230,
#  'name': 231,
#  'voice': 232,
#  'whose': 233,
#  'strange': 234,
#  'true': 235,
#  'way': 236,
#  'get': 237,
#  'passion': 238,
#  'mother': 239,
#  'take': 240,
#  'began': 241,
#  'myself': 242,
#  'pleasure': 243,
#  'saw': 244,
#  'chapter': 245,
#  'beautiful': 246,
#  'many': 247,
#  'give': 248,
#  'dreadful': 249,
#  'just': 250,
#  'wish': 251,
#  'against': 252,
#  'talk': 253,
#  'woman': 254,
#  'few': 255,
#  'put': 256,
#  'seen': 257,
#  'laughed': 258,
#  'real': 259,
#  'met': 260,
#  'murmured': 261,
#  'secret': 262,
#  'each': 263,
#  'painter': 264,
#  'simply': 265,
#  'girl': 266,
#  'wonder': 267,
#  'terrible': 268,
#  'used': 269,
#  'duchess': 270,
#  'because': 271,
#  'merely': 272,
#  'absolutely': 273,
#  'new': 274,
#  'charming': 275,
#  'perhaps': 276,
#  'dead': 277,
#  'often': 278,
#  'years': 279,
#  'heard': 280,
#  'without': 281,
#  'whole': 282,
#  'feel': 283,
#  'though': 284,
#  'behind': 285,
#  'having': 286,
#  'indeed': 287,
#  'youth': 288,
#  'bad': 289,
#  'play': 290,
#  'certainly': 291,
#  'took': 292,
#  'does': 293,
#  'ah': 294,
#  'sense': 295,
#  'suppose': 296,
#  'forget': 297,
#  'stood': 298,
#  'yourself': 299,
#  'read': 300,
#  'mad': 301,
#  'find': 302,
#  'mind': 303,
#  'almost': 304,
#  'air': 305,
#  'works': 306,
#  'joy': 307,
#  'gold': 308,
#  'ask': 309,
#  'painted': 310,
#  'sure': 311,
#  'won': 312,
#  'help': 313,
#  'boy': 314,
#  'answer': 315,
#  'sat': 316,
#  'to-night': 317,
#  'death': 318,
#  'feet': 319,
#  'red': 320,
#  'gutenberg': 321,
#  'hideous': 322,
#  'alan': 323,
#  'use': 324,
#  'matter': 325,
#  'became': 326,
#  'end': 327,
#  'sorry': 328,
#  'pain': 329,
#  'opened': 330,
#  'place': 331,
#  'set': 332,
#  'words': 333,
#  'friend': 334,
#  'god': 335,
#  'delightful': 336,
#  'music': 337,
#  'mean': 338,
#  'whom': 339,
#  'these': 340,
#  'artist': 341,
#  'poor': 342,
#  'nature': 343,
#  'hair': 344,
#  'kind': 345,
#  'sin': 346,
#  'fancy': 347,
#  'become': 348,
#  'full': 349,
#  'campbell': 350,
#  'reason': 351,
#  'makes': 352,
#  'shook': 353,
#  'age': 354,
#  'wild': 355,
#  'seems': 356,
#  'terror': 357,
#  'electronic': 358,
#  'body': 359,
#  'brought': 360,
#  'terms': 361,
#  'call': 362,
#  'past': 363,
#  'live': 364,
#  'chair': 365,
#  'days': 366,
#  'book': 367,
#  'exquisite': 368,
#  'heavy': 369,
#  'expression': 370,
#  'sit': 371,
#  'gone': 372,
#  'understand': 373,
#  'it.': 374,
#  'entered': 375,
#  'same': 376,
#  'sins': 377,
#  'others': 378,
#  'moments': 379,
#  'besides': 380,
#  'home': 381,
#  'large': 382,
#  'garden': 383,
#  'try': 384,
#  'off': 385,
#  'monstrous': 386,
#  'evening': 387,
#  'morning': 388,
#  'you.': 389,
#  'black': 390,
#  'blue': 391,
#  'form': 392,
#  'fingers': 393,
#  'late': 394,
#  '....': 395,
#  'known': 396,
#  'light': 397,
#  'till': 398,
#  'either': 399,
#  'brain': 400,
#  'clock': 401,
#  'walked': 402,
#  'smile': 403,
#  'happy': 404,
#  'times': 405,
#  'foundation': 406,
#  'gentleman': 407,
#  'remember': 408,
#  'however': 409,
#  'married': 410,
#  'charm': 411,
#  'friends': 412,
#  'both': 413,
#  'three': 414,
#  'me.': 415,
#  'part': 416,
#  'senses': 417,
#  'canvas': 418,
#  'lives': 419,
#  'passions': 420,
#  'word': 421,
#  'certain': 422,
#  'except': 423,
#  'heart': 424,
#  'hope': 425,
#  'front': 426,
#  'rose': 427,
#  'drew': 428,
#  'influence': 429,
#  'mere': 430,
#  'romance': 431,
#  'exclaimed': 432,
#  'silver': 433,
#  'best': 434,
#  'broke': 435,
#  'laughing': 436,
#  'together': 437,
#  'sometimes': 438,
#  'called': 439,
#  'perfect': 440,
#  'gave': 441,
#  'changed': 442,
#  'manner': 443,
#  'enough': 444,
#  'narborough': 445,
#  'next': 446,
#  'happened': 447,
#  'keep': 448,
#  'act': 449,
#  'between': 450,
#  'blood': 451,
#  'perfectly': 452,
#  'hear': 453,
#  'wife': 454,
#  'spoke': 455,
#  'leave': 456,
#  'given': 457,
#  'james': 458,
#  'sort': 459,
#  'loved': 460,
#  'money': 461,
#  'horror': 462,
#  'son': 463,
#  'itself': 464,
#  'remembered': 465,
#  'soon': 466,
#  'coat': 467,
#  'theatre': 468,
#  'minutes': 469,
#  'conscious': 470,
#  'smiling': 471,
#  'feeling': 472,
#  'grew': 473,
#  'also': 474,
#  'change': 475,
#  'lying': 476,
#  'didn': 477,
#  'care': 478,
#  'servant': 479,
#  'else': 480,
#  'window': 481,
#  'watched': 482,
#  'fellow': 483,
#  'flung': 484,
#  'person': 485,
#  'memory': 486,
#  'bear': 487,
#  'glanced': 488,
#  'kept': 489,
#  'died': 490,
#  'under': 491,
#  'while': 492,
#  'states': 493,
#  'less': 494,
#  'colour': 495,
#  'fell': 496,
#  'subtle': 497,
#  'prince': 498,
#  'filled': 499,
#  'laugh': 500,
#  'least': 501,
#  'extraordinary': 502,
#  'copyright': 503,
#  'hour': 504,
#  'club': 505,
#  'far': 506,
#  'whatever': 507,
#  'waiting': 508,
#  'fact': 509,
#  'interest': 510,
#  'scarlet': 511,
#  'yellow': 512,
#  'already': 513,
#  'speak': 514,
#  'entirely': 515,
#  'wrong': 516,
#  'present': 517,
#  'studio': 518,
#  'slowly': 519,
#  'screen': 520,
#  'doing': 521,
#  'dinner': 522,
#  'agreement': 523,
#  'started': 524,
#  'cold': 525,
#  'point': 526,
#  'paris': 527,
#  'serious': 528,
#  'marriage': 529,
#  'touch': 530,
#  'street': 531,
#  'good-bye': 532,
#  'themselves': 533,
#  'horribly': 534,
#  'lost': 535,
#  'tired': 536,
#  'tragedy': 537,
#  'send': 538,
#  '‘': 539,
#  'shame': 540,
#  'towards': 541,
#  'child': 542,
#  'stirred': 543,
#  'open': 544,
#  'taking': 545,
#  'bring': 546,
#  'another': 547,
#  'huge': 548,
#  ')': 549,
#  'write': 550,
#  '(': 551,
#  'taken': 552,
#  'london': 553,
#  'idea': 554,
#  'ago': 555,
#  'muttered': 556,
#  'watch': 557,
#  'alone': 558,
#  'crept': 559,
#  'de': 560,
#  'pity': 561,
#  'smiled': 562,
#  'leaves': 563,
#  'glad': 564,
#  'coming': 565,
#  'talking': 566,
#  'license': 567,
#  'country': 568,
#  'five': 569,
#  'fantastic': 570,
#  'shallow': 571,
#  'killed': 572,
#  'hardly': 573,
#  'months': 574,
#  'says': 575,
#  'nearly': 576,
#  'sent': 577,
#  'different': 578,
#  'english': 579,
#  'followed': 580,
#  'means': 581,
#  'impossible': 582,
#  'intellectual': 583,
#  'low': 584,
#  'wanted': 585,
#  'him.': 586,
#  'mouth': 587,
#  'close': 588,
#  'common': 589,
#  'since': 590,
#  'silly': 591,
#  'o': 592,
#  'imagination': 593,
#  'saying': 594,
#  '...': 595,
#  'husband': 596,
#  'agatha': 597,
#  'within': 598,
#  'dress': 599,
#  'donations': 600,
#  'fear': 601,
#  'evil': 602,
#  'stay': 603,
#  'marvellous': 604,
#  'fire': 605,
#  'touched': 606,
#  'jim': 607,
#  'green': 608,
#  'sitting': 609,
#  'copy': 610,
#  'england': 611,
#  'painting': 612,
#  'terribly': 613,
#  'personality': 614,
#  'stopped': 615,
#  'horrid': 616,
#  'society': 617,
#  'marry': 618,
#  'small': 619,
#  'hung': 620,
#  'tears': 621,
#  'literary': 622,
#  'united': 623,
#  'absurd': 624,
#  'century': 625,
#  'silent': 626,
#  'chance': 627,
#  'vulgar': 628,
#  'telling': 629,
#  'aunt': 630,
#  'standing': 631,
#  'shadows': 632,
#  'sought': 633,
#  'experience': 634,
#  'grace': 635,
#  'lines': 636,
#  'rate': 637,
#  'played': 638,
#  'ten': 639,
#  'appeared': 640,
#  'reached': 641,
#  'romantic': 642,
#  'corner': 643,
#  'pale': 644,
#  'hidden': 645,
#  'breath': 646,
#  'reality': 647,
#  'to-day': 648,
#  'valet': 649,
#  'kill': 650,
#  'flowers': 651,
#  'arm': 652,
#  'uncle': 653,
#  'laws': 654,
#  'meet': 655,
#  'taught': 656,
#  'sigh': 657,
#  'dim': 658,
#  'note': 659,
#  'erskine': 660,
#  'shoulders': 661,
#  'pay': 662,
#  'box': 663,
#  'fond': 664,
#  'written': 665,
#  'desire': 666,
#  'glass': 667,
#  'alter': 668,
#  'ebook': 669,
#  'able': 670,
#  'extremely': 671,
#  'herself': 672,
#  'archive': 673,
#  'acting': 674,
#  'mode': 675,
#  'trademark': 676,
#  'sighed': 677,
#  'upstairs': 678,
#  'whispered': 679,
#  'rich': 680,
#  'cigarette': 681,
#  'moved': 682,
#  'strangely': 683,
#  'modern': 684,
#  'ran': 685,
#  'visible': 686,
#  'key': 687,
#  'arms': 688,
#  'curiosity': 689,
#  'library': 690,
#  'discovered': 691,
#  'forgive': 692,
#  'access': 693,
#  'show': 694,
#  'surely': 695,
#  'making': 696,
#  'bit': 697,
#  'determined': 698,
#  'forehead': 699,
#  'seem': 700,
#  'caught': 701,
#  'crime': 702,
#  'grave': 703,
#  'looks': 704,
#  'listen': 705,
#  'forgotten': 706,
#  'stop': 707,
#  'thin': 708,
#  'state': 709,
#  'lay': 710,
#  'pretty': 711,
#  'geoffrey': 712,
#  'top': 713,
#  '*': 714,
#  'nowadays': 715,
#  'side': 716,
#  'effect': 717,
#  'cruel': 718,
#  'lived': 719,
#  'father': 720,
#  'die': 721,
#  'juliet': 722,
#  'wondered': 723,
#  'summer': 724,
#  'silk': 725,
#  'trying': 726,
#  'conscience': 727,
#  'half': 728,
#  'question': 729,
#  'beginning': 730,
#  'store': 731,
#  'paragraph': 732,
#  'fascinating': 733,
#  'revealed': 734,
#  'sunlight': 735,
#  'knows': 736,
#  'type': 737,
#  'whether': 738,
#  'bright': 739,
#  'curtain': 740,
#  'future': 741,
#  'free': 742,
#  'afterwards': 743,
#  'worship': 744,
#  'gilt': 745,
#  'interesting': 746,
#  'lovely': 747,
#  'sound': 748,
#  'year': 749,
#  'laid': 750,
#  'deal': 751,
#  'value': 752,
#  'spoiled': 753,
#  'curiously': 754,
#  'foolish': 755,
#  'cheeks': 756,
#  'trouble': 757,
#  'sky': 758,
#  'flower': 759,
#  'jealous': 760,
#  'information': 761,
#  'continued': 762,
#  'gazing': 763,
#  'seven': 764,
#  'putting': 765,
#  'ideal': 766,
#  'forth': 767,
#  'hate': 768,
#  'coloured': 769,
#  'tedious': 770,
#  'doubt': 771,
#  'lit': 772,
#  'story': 773,
#  'doesn': 774,
#  'finished': 775,
#  'ourselves': 776,
#  'that.': 777,
#  'sailor': 778,
#  'roses': 779,
#  'dare': 780,
#  'comes': 781,
#  'lip': 782,
#  'bell': 783,
#  'hat': 784,
#  'silence': 785,
#  'shot': 786,
#  'selby': 787,
#  'understood': 788,
#  'lead': 789,
#  'dull': 790,
#  'troubled': 791,
#  'mine': 792,
#  'placed': 793,
#  'wrought': 794,
#  'scientific': 795,
#  'floor': 796,
#  'boyhood': 797,
#  'agree': 798,
#  'struck': 799,
#  'second': 800,
#  'public': 801,
#  'birds': 802,
#  'subject': 803,
#  'cry': 804,
#  'paid': 805,
#  'lose': 806,
#  'hall': 807,
#  'somewhat': 808,
#  'yesterday': 809,
#  'beside': 810,
#  'purple': 811,
#  'giving': 812,
#  'annoyed': 813,
#  'lamp': 814,
#  'shown': 815,
#  'ear': 816,
#  'tragic': 817,
#  'letter': 818,
#  'opera': 819,
#  'walking': 820,
#  'during': 821,
#  'worth': 822,
#  'harry.': 823,
#  'straight': 824,
#  'elaborate': 825,
#  'exhibit': 826,
#  'kissed': 827,
#  'led': 828,
#  'infinite': 829,
#  'sister': 830,
#  'indifferent': 831,
#  'windows': 832,
#  'hard': 833,
#  'everybody': 834,
#  'covered': 835,
#  'drove': 836,
#  'dine': 837,
#  'dreadfully': 838,
#  'horse': 839,
#  'king': 840,
#  'throat': 841,
#  'refund': 842,
#  'sad': 843,
#  'genius': 844,
#  'waited': 845,
#  'assure': 846,
#  'trust': 847,
#  'knife': 848,
#  'hated': 849,
#  'half-past': 850,
#  'dark': 851,
#  'mist': 852,
#  'wind': 853,
#  'prayer': 854,
#  'sick': 855,
#  'worse': 856,
#  'murdered': 857,
#  'fatal': 858,
#  'sorrow': 859,
#  'piece': 860,
#  'threw': 861,
#  'month': 862,
#  'cruelty': 863,
#  'sudden': 864,
#  'embroidered': 865,
#  'escape': 866,
#  'living': 867,
#  'grow': 868,
#  'early': 869,
#  'bound': 870,
#  'sleep': 871,
#  'thrust': 872,
#  'hesitated': 873,
#  'scene': 874,
#  'ready': 875,
#  'frowned': 876,
#  'stage': 877,
#  'shadow': 878,
#  'adrian': 879,
#  'phrase': 880,
#  'beneath': 881,
#  'including': 882,
#  'coarse': 883,
#  'greek': 884,
#  'rushed': 885,
#  'queen': 886,
#  'following': 887,
#  'turn': 888,
#  'eye': 889,
#  'view': 890,
#  'destroy': 891,
#  'duke': 892,
#  'shaking': 893,
#  'held': 894,
#  'mrs.': 895,
#  'winter': 896,
#  'thinking': 897,
#  'stir': 898,
#  'follow': 899,
#  'fall': 900,
#  'remain': 901,
#  'older': 902,
#  'passing': 903,
#  'interested': 904,
#  'brother': 905,
#  'aside': 906,
#  'younger': 907,
#  'spent': 908,
#  'history': 909,
#  'locked': 910,
#  'playing': 911,
#  'shrugged': 912,
#  'marred': 913,
#  'return': 914,
#  'quarrel': 915,
#  'tea': 916,
#  'realize': 917,
#  'faces': 918,
#  'dressed': 919,
#  'natural': 920,
#  'outside': 921,
#  'ivory': 922,
#  'sofa': 923,
#  'nonsense': 924,
#  'books': 925,
#  'pure': 926,
#  'fashionable': 927,
#  'moral': 928,
#  'george': 929,
#  'twenty': 930,
#  'leaning': 931,
#  'houses': 932,
#  'wondering': 933,
#  'her.': 934,
#  'high': 935,
#  'town': 936,
#  'ceased': 937,
#  'clever': 938,
#  'hundred': 939,
#  'fascinated': 940,
#  'several': 941,
#  'watching': 942,
#  'turning': 943,
#  'friendship': 944,
#  'safe': 945,
#  'presence': 946,
#  'week': 947,
#  'worshipped': 948,
#  'spirit': 949,
#  'madness': 950,
#  'cup': 951,
#  'wotton': 952,
#  'showed': 953,
#  'dream': 954,
#  'nice': 955,
#  'corruption': 956,
#  'wall': 957,
#  'promised': 958,
#  'image': 959,
#  'shrill': 960,
#  'delicate': 961,
#  'golden': 962,
#  'cut': 963,
#  'misshapen': 964,
#  'figure': 965,
#  'wrote': 966,
#  'mask': 967,
#  'paper': 968,
#  'received': 969,
#  'thomas': 970,
#  'peril': 971,
#  'run': 972,
#  'dawn': 973,
#  'sorrows': 974,
#  'isn': 975,
#  'altered': 976,
#  'dangerous': 977,
#  'closed': 978,
#  'six': 979,
#  'somewhere': 980,
#  'ill': 981,
#  'hubbard': 982,
#  'examined': 983,
#  'hansom': 984,
#  'study': 985,
#  'allowed': 986,
#  'polished': 987,
#  'rough': 988,
#  'ground': 989,
#  'copies': 990,
#  'keeping': 991,
#  'to-morrow': 992,
#  'confess': 993,
#  'knock': 994,
#  'theory': 995,
#  'kelso': 996,
#  'medium': 997,
#  'handkerchief': 998,
#  'refuse': 999,
#  ...}

# %% [markdown]
# Now we pick a word from the corpus (remember this is lowercase) and see what the vector associated with it is. This is not human-readable, but it's this list (array) of numbers that helps us define the word in context.

# %%
model.wv.get_vector("opera", norm=True)
# Out:
# array([-0.02300198,  0.10392751,  0.06917968,  0.00087015,  0.08046457,
#        -0.16414404,  0.08598847,  0.32030562, -0.03326023, -0.07066453,
#        -0.01022524, -0.12898058, -0.02492042,  0.0164675 ,  0.0429481 ,
#        -0.0087422 ,  0.03437307, -0.08430237, -0.04209103, -0.31759465,
#         0.03946931,  0.05837446,  0.05124584, -0.02684638, -0.03775502,
#         0.06503068, -0.10902361, -0.01293605, -0.10243758, -0.02254437,
#         0.01327006, -0.02744054,  0.0799185 , -0.14636578, -0.04929849,
#         0.155927  ,  0.00082646, -0.08801144, -0.0742923 , -0.16313319,
#        -0.02356712, -0.08883481, -0.05706111,  0.08534967,  0.11698513,
#        -0.12089007, -0.06675842, -0.08507375,  0.04996393,  0.09675474,
#         0.07898589, -0.11334648, -0.09363117, -0.07235375, -0.01971546,
#        -0.02772869,  0.06637437, -0.0249155 , -0.15590079,  0.06550416,
#         0.02264432,  0.00939584,  0.0259524 ,  0.01311568, -0.18262935,
#         0.16717367,  0.0661911 ,  0.1001243 , -0.16852787,  0.05299318,
#        -0.07083163,  0.06782045,  0.07063666, -0.02147122,  0.14515641,
#         0.04676477,  0.02028383,  0.0172435 , -0.15413074,  0.04395543,
#        -0.10865241,  0.09067546, -0.09700752,  0.19248195,  0.03186917,
#        -0.02507841,  0.07477903,  0.15508252,  0.12913278, -0.0511676 ,
#         0.15381876,  0.05455776,  0.05463689,  0.03112894,  0.28221458,
#         0.14198796,  0.05398616, -0.09168518,  0.02063756, -0.0225841 ],
#       dtype=float32)

# %% [markdown]
# Find all the words most similar to a word you've chosen. Notice that this similarity is not the same as the vector representation above.
#
# After you run this cell, make a note of the top 5 words. Go back and change the number of words in the vector and re-run the cells in between. Did it change?

# %%
model.wv.most_similar('opera')
# Out:
# [('then', 0.9943591356277466),
#  ('found', 0.9937798976898193),
#  ('de', 0.9937676191329956),
#  ('words', 0.9936447143554688),
#  ('once', 0.9935680627822876),
#  ('true', 0.9935435652732849),
#  (')', 0.9934912919998169),
#  ('while', 0.9934853315353394),
#  ('away', 0.993437647819519),
#  ('new', 0.9933927655220032)]

# %% [markdown]
# Now see how similar some words are. Change these words if you change the text.

# %%
model.wv.similarity('painting', 'dorian')
# Out:
# 0.9024992

# %%
model.wv.similarity('dorian', 'murdered')
# Out:
# 0.954334

# %% [markdown]
# Finally visualize the result. There's a lot of code here, it's really just for visualization. The first part is the dimensionality reduction (using t-SNE). The second part puts it on a visualization.
#
#
# Spend more time exploring the visualization than breaking down the code.
#
# The visualization that results is very hard to see. If you are in a Jupyter Notebook, there are tools in the upper right corner of the cell that has the visualization in it (they appear on hover). You can zoom in on the visualization to see the words and the relationships between the words.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# !pip install plotly
# !pip install --upgrade plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.17.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.1)

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)

# %%
def reduce_dimensions(model):
    num_dimensions = 2  # final num dimensions (2D, 3D, etc)

    # extract the words & their vectors, as numpy arrays
    vectors = np.asarray(model.wv.vectors)
    labels = np.asarray(model.wv.index_to_key)  # fixed-width numpy strings

    # reduce using t-SNE
    tsne = TSNE(n_components=num_dimensions, random_state=0)
    vectors = tsne.fit_transform(vectors)

    x_vals = [v[0] for v in vectors]
    y_vals = [v[1] for v in vectors]
    return x_vals, y_vals, labels


x_vals, y_vals, labels = reduce_dimensions(model)

# %%
import matplotlib.pyplot as plt

def plot_word_vectors(x_vals, y_vals, labels):
    plt.figure(figsize=(45, 21))
    plt.scatter(x_vals, y_vals, alpha=0.5)

    for x, y, label in zip(x_vals, y_vals, labels):
        plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')

    plt.show()

x_vals, y_vals, labels = reduce_dimensions(model)
plot_word_vectors(x_vals, y_vals, labels)

# %%
import plotly.express as px
import pandas as pd

def plot_with_plotly(x_vals, y_vals, labels):
    data = {'x': x_vals, 'y': y_vals, 'labels': labels}
    df = pd.DataFrame(data)

    fig = px.scatter(df, x='x', y='y', text='labels')
    fig.update_traces(textposition='top right')

    fig.show()

# Assuming you already have x_vals, y_vals, and labels
x_vals, y_vals, labels = reduce_dimensions(model)

plot_with_plotly(x_vals, y_vals, labels)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.26.0.min.js"></script>                <div id="8b8e0038-a807-465c-8b2a-b8ffece2a86c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8b8e0038-a807-465c-8b2a-b8ffece2a86c")) {                    Plotly.newPlot(                        "8b8e0038-a807-465c-8b2a-b8ffece2a86c",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003elabels=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":[",",".","the","of","and","to","a","i","\u201c","\u201d","he","you","that","it","in","was","his","is","had","\u2019","with","him","for","as","?","at","have","not","me","be","one","her","she","t","dorian","what","but","are","!","on","there","they","would","my","all","or","from","s","said","don","were","lord","so","if","by","been","henry","an","am","about","who","no","some","life","when","your","like","will","them","gray","can","this","do","man","we","never","has","know","harry","over","must","into","out",";","their","any","basil","up","how","then","could","more","own","now","its","things","which","see","very","than","think","come","something","seemed","thing","us","should","only","go","always","made","love","quite","eyes","want","time","face","himself","good","really","too","after","people","away","did","down","back","came","cried","looked","world","say","tell","why","hallward","look","nothing","project","work","room","answered","much","other","little","going","upon","through","thought","sibyl","such","shall","most","round","mr.","yes","told","ever","our","once","felt","great","before","dear","art","men","long","picture","yet","lady","young","again","anything","moment","let","everything","women","those","door","make","hand","went","being","two","old","across","asked","might","soul","passed","afraid","night","where","every","well","day","looking","wonderful","gutenberg\u2122","vane","table","turned","got","beauty","lips","right","left","course","even","head","portrait","lad","white","hands","sir","believe","house","better","done","still",":","horrible","here","oh","found","first","may","curious","last","suddenly","rather","knew","name","voice","whose","strange","true","way","get","passion","mother","take","began","myself","pleasure","saw","chapter","beautiful","many","give","dreadful","just","wish","against","talk","woman","few","put","seen","laughed","real","met","murmured","secret","each","painter","simply","girl","wonder","terrible","used","duchess","because","merely","absolutely","new","charming","perhaps","dead","often","years","heard","without","whole","feel","though","behind","having","indeed","youth","bad","play","certainly","took","does","ah","sense","suppose","forget","stood","yourself","read","mad","find","mind","almost","air","works","joy","gold","ask","painted","sure","won","help","boy","answer","sat","to-night","death","feet","red","gutenberg","hideous","alan","use","matter","became","end","sorry","pain","opened","place","set","words","friend","god","delightful","music","mean","whom","these","artist","poor","nature","hair","kind","sin","fancy","become","full","campbell","reason","makes","shook","age","wild","seems","terror","electronic","body","brought","terms","call","past","live","chair","days","book","exquisite","heavy","expression","sit","gone","understand","it.","entered","same","sins","others","moments","besides","home","large","garden","try","off","monstrous","evening","morning","you.","black","blue","form","fingers","late","....","known","light","till","either","brain","clock","walked","smile","happy","times","foundation","gentleman","remember","however","married","charm","friends","both","three","me.","part","senses","can ...

# %%
def plot_with_plotly(x_vals, y_vals, labels, plot_in_notebook=True):
    from plotly.offline import init_notebook_mode, iplot, plot
    import plotly.graph_objs as go

    trace = go.Scatter(x=x_vals, y=y_vals, mode='text', text=labels)
    data = [trace]

    if plot_in_notebook:
        init_notebook_mode(connected=True)
        iplot(data, filename='word-embedding-plot')
    else:
        plot(data, filename='word-embedding-plot.html')


def plot_with_matplotlib(x_vals, y_vals, labels):
    import matplotlib.pyplot as plt
    import random

    random.seed(0)

    plt.figure(figsize=(12, 12))
    plt.scatter(x_vals, y_vals)

    #
    # Label randomly subsampled 25 data points
    #
    indices = list(range(len(labels)))
    selected_indices = random.sample(indices, 25)
    for i in selected_indices:
        plt.annotate(labels[i], (x_vals[i], y_vals[i]))

try:
    get_ipython()
except Exception:
    plot_function = plot_with_matplotlib
else:
    plot_function = plot_with_plotly

plot_function(x_vals, y_vals, labels)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="64fd1814-b11a-4940-8881-c94945eb3af0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64fd1814-b11a-4940-8881-c94945eb3af0")) {                    Plotly.newPlot(                        "64fd1814-b11a-4940-8881-c94945eb3af0",                        [{"mode":"text","text":[",",".","the","of","and","to","a","i","\u201c","\u201d","he","you","that","it","in","was","his","is","had","\u2019","with","him","for","as","?","at","have","not","me","be","one","her","she","t","dorian","what","but","are","!","on","there","they","would","my","all","or","from","s","said","don","were","lord","so","if","by","been","henry","an","am","about","who","no","some","life","when","your","like","will","them","gray","can","this","do","man","we","never","has","know","harry","over","must","into","out",";","their","any","basil","up","how","then","could","more","own","now","its","things","which","see","very","than","think","come","something","seemed","thing","us","should","only","go","always","made","love","quite","eyes","want","time","face","himself","good","really","too","after","people","away","did","down","back","came","cried","looked","world","say","tell","why","hallward","look","nothing","project","work","room","answered","much","other","little","going","upon","through","thought","sibyl","such","shall","most","round","mr.","yes","told","ever","our","once","felt","great","before","dear","art","men","long","picture","yet","lady","young","again","anything","moment","let","everything","women","those","door","make","hand","went","being","two","old","across","asked","might","soul","passed","afraid","night","where","every","well","day","looking","wonderful","gutenberg\u2122","vane","table","turned","got","beauty","lips","right","left","course","even","head","portrait","lad","white","hands","sir","believe","house","better","done","still",":","horrible","here","oh","found","first","may","curious","last","suddenly","rather","knew","name","voice","whose","strange","true","way","get","passion","mother","take","began","myself","pleasure","saw","chapter","beautiful","many","give","dreadful","just","wish","against","talk","woman","few","put","seen","laughed","real","met","murmured","secret","each","painter","simply","girl","wonder","terrible","used","duchess","because","merely","absolutely","new","charming","perhaps","dead","often","years","heard","without","whole","feel","though","behind","having","indeed","youth","bad","play","certainly","took","does","ah","sense","suppose","forget","stood","yourself","read","mad","find","mind","almost","air","works","joy","gold","ask","painted","sure","won","help","boy","answer","sat","to-night","death","feet","red","gutenberg","hideous","alan","use","matter","became","end","sorry","pain","opened","place","set","words","friend","god","delightful","music","mean","whom","these","artist","poor","nature","hair","kind","sin","fancy","become","full","campbell","reason","makes","shook","age","wild","seems","terror","electronic","body","brought","terms","call","past","live","chair","days","book","exquisite","heavy","expression","sit","gone","understand","it.","entered","same","sins","others","moments","besides","home","large","garden","try","off","monstrous","evening","morning","you.","black","blue","form","fingers","late","....","known","light","till","either","brain","clock","walked","smile","happy","times","foundation","gentleman","remember","however","married","charm","friends","both","three","me.","part","senses","canvas","lives","passions","word","certain","except","heart","hope","front","rose","drew","influence","mere","romance","exclaimed","silver","best","broke","laughing","together","sometimes","called","perfect","gave","changed","manner","enough","narbor ...

# %% [markdown]
# ## Part 2 : GloVe

# %% [markdown]
# **BEFORE you move on, did you:**
#
# * DOWNLOAD the [Embeddings file for Part 2 here](https://drive.google.com/file/d/1NQ_7ERV3eiUnPCoIW7I8yi4TZMiu2cEQ/view?usp=sharing)
# * Unzip the file
# * Move it to the folder where you are writing your code.

# %%
import numpy as np
from scipy import spatial
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %% [markdown]
# There are a few files in the `glove/6B` folder. These are the embeddings. You can open them and see them in any text editor. 50d is the smallest one. Each word has 50 dimensions. This means it is defined in terms of 50 other words.
#
# This lab uses the 100d file. If it's running slower than you like, feel free to use 50d instead. If you want more accurate word relationships, use one of the larger files.

# %%
#establish an empty dictionary
embeddings_dict = {}

#open the file and read it into the dictionary
with open("/content/drive/MyDrive/Colab Notebooks/glove.6B/glove.6B.100d.txt", 'r', encoding="utf-8") as f:
    for line in f:
        values = line.split()
        word = values[0]
        vector = np.asarray(values[1:], "float32")
        embeddings_dict[word] = vector

# %%
#find the Euclidean distance between the vectors for words and 1 or more other words.
#sort the resulting word distances.
def find_closest_embeddings(embedding):
    return sorted(embeddings_dict.keys(), key=lambda word:
                  spatial.distance.euclidean(embeddings_dict[word], embedding))

# %% [markdown]
# Now try it out - pick some words to experiment with. This experimentation section is the most important part of Part 2.

# %%
print(find_closest_embeddings(
    embeddings_dict["economic"]
)[:20])
# Out:
# ['economic', 'economy', 'financial', 'economies', 'policy', 'global', 'growth', 'crisis', 'development', 'stability', 'impact', 'reforms', 'recovery', 'progress', 'trade', 'monetary', 'emerging', 'policies', 'downturn', 'change']

# %%
print(find_closest_embeddings(
    embeddings_dict["official"]
)[:20])
# Out:
# ['official', 'according', 'ministry', 'statement', 'officials', 'reports', 'saying', 'earlier', 'citing', 'sources', 'confirmed', 'referring', 'agency', 'issued', 'office', 'meanwhile', 'quoted', 'press', 'afp', 'adding']

# %% [markdown]
# Now pick 2 words and see how it changes. Note that the `+` actually indicates that the vectors are being added. This may have slightly unexpected results.

# %%
print(find_closest_embeddings(
    embeddings_dict["economic"] + embeddings_dict["official"]
)[:20])
# Out:
# ['economic', 'official', 'government', 'policy', 'financial', 'economy', 'report', 'political', 'foreign', 'trade', 'development', 'crisis', 'recent', 'security', 'country', 'according', 'administration', 'officials', 'china', 'current']

# %% [markdown]
# See what happens with a 3rd. These embeddings are basically being triangulated - and this list is what is nearest to the center of these 3 points.

# %%
print(find_closest_embeddings(
    embeddings_dict["economic"] + embeddings_dict["official"] + embeddings_dict["members"]
)[:20])
# Out:
# ['economic', 'government', 'official', 'leaders', 'officials', 'political', 'members', 'meeting', 'foreign', 'security', 'countries', 'the', 'policy', 'nations', 'country', 'that', 'report', 'financial', 'according', 'its']

# %% [markdown]
# Now transform the dictionary into an array so that we can do dimensionality reduction so we can visualize the words

# %%
words =  list(embeddings_dict.keys())
vectors = [embeddings_dict[word] for word in words]
X = np.asarray(vectors)

# %% [markdown]
# Now do the dimensionality reduction with t-SNE.

# %%
tsne = TSNE(n_components=2, random_state=0)
Y = tsne.fit_transform(X[:1000])

# %% [markdown]
# Plot the points

# %%
plt.scatter(Y[:, 0], Y[:, 1])

# %% [markdown]
# Annotate a few of the words.

# %%
for label, x, y in zip(words, X[:, 0], Y[:, 1]):
    plt.annotate(label, xy=(x, y), xytext=(0, 0), textcoords="offset points")
plt.show()
